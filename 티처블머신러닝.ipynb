# %%
import tensorflow as tf
model = tf.keras.models.load_model('c:/data/myMnist.h5')

# %%
model.summary()    ## w = 784 개, b = 1개,     785개 파라미터 * 128개 = 100480   (w 100480개, b 128개) 짜리가 10개 있음.
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# ...
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.get_weights()
# Out:
# [array([[-0.05227647,  0.01591615, -0.04714846, ..., -0.01523452,
#           0.07385189,  0.04628729],
#         [ 0.04252898,  0.0647539 , -0.07112169, ..., -0.07788388,
#          -0.02753631,  0.01156185],
#         [-0.0353706 ,  0.07501728,  0.02223109, ...,  0.06629509,
#           0.06859171,  0.03057472],
#         ...,
#         [-0.05592507,  0.07714764,  0.04659373, ..., -0.06743716,
#           0.0450084 , -0.04803765],
#         [ 0.06366863,  0.06063706,  0.05872829, ..., -0.06822527,
#           0.04382715,  0.0030236 ],
#         [ 0.04972988, -0.0036002 ,  0.03809156, ..., -0.05292156,
#          -0.03349883,  0.02792647]], dtype=float32),
#  array([ 0.1254772 ,  0.13949846, -0.16568722, -0.10951597,  0.04239623,
#         -0.38943854,  0.06382996, -0.00922524,  0.05345003, -0.18000804,
#         -0.16479057,  0.00077844, -0.04907391, -0.00905409, -0.13361268,
#         -0.02422312,  0.02655353, -0.23412097,  0.07536568,  0.04274862,
# ...

# %%
from PIL import Image   ####OPENCV, SKIMAGE, PILLOW 이미지처리 모듈
import numpy as np
img = Image.open('c:/data/Mnist/num4.jpg').resize((28,28))
img
np.array(img)
# Out:
# array([[[255, 255, 255],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [255, 255, 255],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[253, 253, 253],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[253, 253, 253],
#         [255, 255, 255],
#         [253, 253, 253],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [254, 254, 254],
#         [254, 254, 254],
# ...

# %%
np.shape(img)
# Out:
# (28, 28, 3)

# %%
import matplotlib.pyplot as plt
img=Image.open('c:/data/Mnist/num4.jpg').resize((28,28)).convert('L')
img = 255-np.array(img)
img = img/255
np.shape(img)
plt.imshow(img, cmap='gray')

img
# Out:
# array([[0.        , 0.00392157, 0.00392157, 0.        , 0.        ,
#         0.        , 0.00784314, 0.        , 0.00392157, 0.        ,
#         0.01176471, 0.00392157, 0.        , 0.        , 0.        ,
#         0.00784314, 0.00784314, 0.        , 0.        , 0.00392157,
#         0.        , 0.        , 0.01176471, 0.        , 0.        ,
#         0.        , 0.00392157, 0.00392157],
#        [0.00784314, 0.        , 0.        , 0.        , 0.01568627,
#         0.00392157, 0.        , 0.        , 0.        , 0.01176471,
#         0.        , 0.        , 0.01568627, 0.29019608, 0.74117647,
#         0.37647059, 0.        , 0.01176471, 0.        , 0.        ,
#         0.00392157, 0.        , 0.        , 0.01568627, 0.        ,
#         0.        , 0.        , 0.        ],
#        [0.00784314, 0.        , 0.00784314, 0.        , 0.        ,
#         0.00784314, 0.00784314, 0.01568627, 0.00392157, 0.00392157,
# ...

# %%
plt.imshow(img, cmap='gray')

# %%
img = np.array(img)

# %%
img.max() ,img.min()
# Out:
# (1.0, 0.0)

# %%
predict_Num = model.predict(img.reshape(-1,28,28)) ##어레이가 모여 텐서가 되고, 반드시 텐서 단위로 들어가야함

# %%
predict_Num
# Out:
# array([[8.08122902e-09, 1.47849955e-08, 7.36269139e-05, 7.77842288e-08,
#         8.35993048e-03, 2.98101810e-07, 5.86474198e-04, 9.50196981e-01,
#         4.07817811e-02, 7.61845513e-07]], dtype=float32)

# %%
np.argmax(predict_Num) ##가장 큰 값이 있는 위치
# Out:
# 7

# %%
from glob import glob
fileList = glob('c:/data/Mnist/*.jpg')
for cnt, x in enumerate(fileList):
    plt.figure(figsize=(10,3))
    img = Image.open(x).resize((28,28)).convert('L')
    img = 255-np.array(img)
    img = img/255
    predict_Num= model.predict(img.reshape(-1,28,28))
    plt.subplot(1,len(fileList),cnt+1)
    plt.imshow(img, cmap='gray')
    plt.title('pred-->'+str(np.argmax(predict_Num)))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from glob import glob

fileList=glob('c:/data/Mnist/*.jpg')
print(fileList)
plt.figure(figsize=(10,3))
    
for cnt,x  in enumerate(fileList):
    img=Image.open(x).resize((28,28)).convert('L')
    img=255-np.array(img)
    img=img/255
    np.shape(img)
    predict_Num=model.predict(img.reshape(-1,28,28))  
    plt.subplot(1,len(fileList),cnt+1)
    plt.imshow(img, cmap='gray')
    plt.title('pred-->'+str(np.argmax(predict_Num)))
# Out:
# ['c:/data/Mnist\\num1.jpg', 'c:/data/Mnist\\num2.jpg', 'c:/data/Mnist\\num3.jpg', 'c:/data/Mnist\\num4.jpg', 'c:/data/Mnist\\num5.jpg', 'c:/data/Mnist\\num6.jpg', 'c:/data/Mnist\\num7.jpg', 'c:/data/Mnist\\num8.jpg', 'c:/data/Mnist\\num9.jpg']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 15
#      13 img=img/255
#      14 np.shape(img)
# ---> 15 predict_Num=model.predict(img.reshape(-1,28,28))
#      16 plt.subplot(1,len(fileList),cnt+1)
#      17 plt.imshow(img, cmap='gray')
#
# File c:\Users\user\miniconda3\envs\gpu\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
# ...

# %%
model=tf.keras.models.load_model('c:/data/keras_model.h5')
model.summary()
import matplotlib.pyplot as plt

img = Image.open('c:/data/다운로드.png').resize((224,224)).convert('RGB')
print(np.shape(img))
img = np.array(img) #행렬변환   
img = (img/127.5)-1 #티쳐블머신러닝의 스케일링
plt.imshow(img)

img = img.reshape(1,224,224,3)
np.shape(img)
model.predict(img)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  sequential_1 (Sequential)   (None, 1280)              410208
#
#  sequential_3 (Sequential)   (None, 2)                 128300
#
# ...
# Total params: 538,508
# Trainable params: 524,428
# Non-trainable params: 14,080
# _________________________________________________________________
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# ...

# %%
import tensorflow as tf
from keras.models import load_model  # TensorFlow is required for Keras to work
from PIL import Image, ImageOps  # Install pillow instead of PIL
import numpy as np

# Disable scientific notation for clarity
np.set_printoptions(suppress=True)

model = load_model("c:/data/keras_Model.h5", compile=False)
class_names = open("c:/data/labels.txt", "r").readlines()

data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

image = Image.open("c:/data/Mnist/num1.jpg").convert("RGB")
size = (224, 224)
image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)
image_array = np.asarray(image)

normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1

data[0] = normalized_image_array

prediction = model.predict(data) ###예측한 결과는 [0의 위치 확률값, 1의 위치 확률값.....]
index = np.argmax(prediction) ###가장 큰 값을 갖고 있는 위치값
# class_name = class_names[index]   ###라벨값
# confidence_score = prediction[0][index]

# print("Class:", class_name[2:], end="")
# print("Confidence Score:", confidence_score)
# Out:
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
